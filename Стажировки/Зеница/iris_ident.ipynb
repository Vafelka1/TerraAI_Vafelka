# %%
# !! pip install open-metric-learning
# !! pip install pytorch-metric-learning
# !! pip install pillow==9.0.0
# Out:
# ['Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/',
#  'Collecting pillow==9.0.0',
#  '  Downloading Pillow-9.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)',
#  '\x1b[?25l     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/4.3 MB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━\x1b\x1b╺\x1b\x1b━━━━━━━━━━━━━━━━━━━━━\x1b \x1b2.0/4.3 MB\x1b \x1b58.1 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╸\x1b \x1b4.3/4.3 MB\x1b \x1b81.2 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b4.3/4.3 MB\x1b \x1b52.8 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25hInstalling collected packages: pillow',
#  '  Attempting uninstall: pillow',
#  '    Found existing installation: Pillow 8.4.0',
#  '    Uninstalling Pillow-8.4.0:',
#  '      Successfully uninstalled Pillow-8.4.0',
#  'Successfully installed pillow-9.0.0']

# %%
import torch
from tqdm import tqdm

from oml.datasets.base import DatasetWithLabels
from oml.losses.triplet import TripletLossWithMiner
from oml.miners.inbatch_all_tri import AllTripletsMiner
from oml.models.vit.vit import ViTExtractor
from oml.samplers.balance import BalanceSampler
from oml.datasets.base import DatasetQueryGallery
from oml.metrics.embeddings import EmbeddingMetrics
from oml.utils.dataframe_format import check_retrieval_dataframe_format
from oml.utils.misc_torch import PCA
from oml.inference.flat import inference_on_images
from oml.registry.transforms import get_transforms_for_pretrained
from oml.utils.misc_torch import pairwise_dist
from pytorch_metric_learning import losses, distances, reducers, miners
import pandas as pd
from oml.transforms.images.torchvision import get_normalisation_resize_torch
from oml.models.meta.siamese import ConcatSiamese
from oml.miners.pairs import PairsMiner
from oml.inference.flat import inference_on_dataframe
from torch.nn import BCEWithLogitsLoss
from torch.utils.data import DataLoader
from oml.retrieval.postprocessors.pairwise import PairwiseImagesPostprocessor
from pprint import pprint

# %%
# %cd '/content/drive/MyDrive/iris'
# Out:
# /content/drive/MyDrive/iris

# %%
import os
from os import walk
import pandas as pd

# Create a sample DataFrame
data = {'label': [],
        'src_file': [],
        'split': [],
        'is_query': [],
        'is_gallery': [],
        'eye': [],
        'ds': [],
        'path': []
        }
df_zenica = pd.DataFrame(data)

# list to store files
res = []

rootdir = 'ZENICA_IRIS'

def listdirs(rootdir):
    for file in os.listdir(rootdir):
        d = os.path.join(rootdir, file)
        if os.path.isdir(d):
            #print(d)
            listdirs(d)
        else:
          res.append(d)



listdirs(rootdir)

# %%
is_query=1
is_gallery=0.0
ds='zenica'

for r in res:
  z,q,label,lr,full,src_file=r.split('/')

  if lr=='right':
    lr='R'
  else:
     lr='L'


  if (is_query==1.0):
     is_query=0.0
     is_gallery=1.0
  else:
     is_query=1.0
     is_gallery=0.0


  new_row = {'label': label,
             'src_file': src_file,
             'split': 'validation',
             'is_query': is_query,
             'is_gallery': is_gallery,
             'eye': lr,
             'ds': ds,
             'path': r
             }

  df_zenica.loc[len(df_zenica)] = new_row

# %%
csvpath="/content/drive/MyDrive/iris/zenica_iris.csv"
#df_zenica.to_csv(csvpath,index=False)

# %%
import pandas as pd

csvpath="/content/drive/MyDrive/iris/zenica_iris.csv"
df_zenica = pd.read_csv(csvpath)

# %%
df_zenica
# Out:
#      label             src_file       split  is_query  is_gallery eye      ds  \
# 0        5  05_right_full_8.png  validation       0.0         1.0   R  zenica
# 1        5  05_right_full_7.png  validation       1.0         0.0   R  zenica
# 2        5  05_right_full_6.png  validation       0.0         1.0   R  zenica
# 3        5  05_right_full_5.png  validation       1.0         0.0   R  zenica
# 4        5  05_right_full_4.png  validation       0.0         1.0   R  zenica
# ..     ...                  ...         ...       ...         ...  ..     ...
# 155      1  01_right_full_4.png  validation       1.0         0.0   R  zenica
# 156      1  01_right_full_5.png  validation       0.0         1.0   R  zenica
# 157      1  01_right_full_6.png  validation       1.0         0.0   R  zenica
# 158      1  01_right_full_7.png  validation       0.0         1.0   R  zenica
# 159      1  01_right_full_8.png  validation       1.0         0.0   R  zenica
#
#                                                   path
# 0    ZENICA_IRIS/1920x1080/5/right/full/05_right_fu...
# 1    ZENICA_IRIS/1920x1080/5/right/full/05_right_fu...
# 2    ZENICA_IRIS/1920x1080/5/right/full/05_right_fu...
# 3    ZENICA_IRIS/1920x1080/5/right/full/05_right_fu...
# 4    ZENICA_IRIS/1920x1080/5/right/full/05_right_fu...
# ..                                                 ...
# 155  ZENICA_IRIS/1920x1080/1/right/full/01_right_fu...
# 156  ZENICA_IRIS/1920x1080/1/right/full/01_right_fu...
# 157  ZENICA_IRIS/1920x1080/1/right/full/01_right_fu...
# 158  ZENICA_IRIS/1920x1080/1/right/full/01_right_fu...
# 159  ZENICA_IRIS/1920x1080/1/right/full/01_right_fu...
#
# [160 rows x 8 columns]

# %%
# %cd /content/drive/MyDrive/iris
# Out:
# /content/drive/MyDrive/iris

# %%
# !python3 ./run_iris_detect_knn3.py
# Out:
# init success
# Prefix <model.> was removed from the state dict.
# [31.78305327664316, 10.199534042785553, 12.036388538421795, 18.66858299954599, 14.215654711169215, 26.291762491364928, 12.200306897915327, 17.461309769521513, 9.010651537235711, 13.007028880300403, 13.55402443443056, 10.212345834640004, 24.219464455187563, 10.980665033486666, 13.18746644508468, 11.51665518098103, 9.989358198687226, 21.544532963950868, 14.442218752501887, 15.88593162160558, 14.614346267325441, 12.237891616244095, 13.724246234033505, 32.52748612351752, 27.65044739621653, 16.057250593761665, 15.358520111477162, 14.914980716724827, 19.78496537111774, 16.75649761741229, 16.752476751063465, 15.471702586742584, 18.396485100760415, 21.2738915267837, 23.329106120527047, 20.21876056558843, 23.693420475484857, 25.286318201422556, 26.7466365803137, 21.227162734198384, 22.886253048790692, 21.87687910455851, 12.1478986516348, 8.590691039385579, 18.456906828284332, 13.173199606254014, 17.150388734376676, 8.313905984243732, 12.574092545576661, 16.765037960074363, 33.100283747721676, 17.697293970186163, 16.68045683969295, 19.293189014105064, 18.948624066245713, 20.598712236467144, 13.69850977011277, 14.018681731889059, 24.327504056381972, 24.96747762519962, 23.619083047069694, 18.855066953068278, 16.96769157466763, 31.2608516314985, 12.856600456301376, 17.8959965666971, 14.868986052042025, 10.708442024441291, 12.956571960129262, 19.05640111195825, 12.408558359319612, 17.713479740072337, 15.135775172202994, 21.17027280030782, 16.054327284584268, 25.86167026256292, 14.247278321672365, 23.06417385736277, 15.736411393792661, 20.681467150473, 14.359517392520326, 17.173301130781923]
# [3, 1, 2, 0, 5, 4, 6, 2, 8, 8, 10, 10, 13, 12, 15, 15, 16, 17, 19, 16, 21, 22, 22, 21, 25, 25, 26, 27, 29, 29, 30, 31, 33, 32, 35, 33, 35, 33, 34, 34, 32, 34, 38, 40, 41, 41, 43, 43, 45, 42, 48, 48, 48, 46, 51, 52, 52, 50, 60, 59, 57, 54, 59, 60, 60, 61, 64, 64, 63, 62, 66, 68, 68, 67, 70, 72, 73, 76, 76, 75, 74, 76]
# Match: N query 0  closest to: 3 distance: 18.66858299954599
# Match: query   label: 5 path:  ZENICA_IRIS/1920x1080/5/right/full/05_right_full_7.png
# Match: predict label: 5 path:  ZENICA_IRIS/1920x1080/5/right/full/05_right_full_2.png
#
#
# Match: N query 1  closest to: 1 distance: 10.199534042785553
# Match: query   label: 5 path:  ZENICA_IRIS/1920x1080/5/right/full/05_right_full_5.png
# Match: predict label: 5 path:  ZENICA_IRIS/1920x1080/5/right/full/05_right_full_6.png
#
#
# Match: N query 2  closest to: 2 distance: 12.036388538421795
# Match: query   label: 5 path:  ZENICA_IRIS/1920x1080/5/right/full/05_right_full_3.png
# Match: predict label: 5 path:  ZENICA_IRIS/1920x1080/5/right/full/05_right_full_4.png
#
#
# Match: N query 3  closest to: 0 distance: 31.78305327664316
# Match: query   label: 5 path:  ZENICA_IRIS/1920x1080/5/right/full/05_right_full_1.png
# Match: predict label: 5 path:  ZENICA_IRIS/1920x1080/5/right/full/05_right_full_8.png
#
#
# Match: N query 4  closest to: 5 distance: 26.291762491364928
# Match: query   label: 5 path:  ZENICA_IRIS/1920x1080/5/left/full/05_left_full_7.png
# Match: predict label: 5 path:  ZENICA_IRIS/1920x1080/5/left/full/05_left_full_6.png
#
#
# Match: N query 5  closest to: 4 distance: 14.215654711169215
# Match: query   label: 5 path:  ZENICA_IRIS/1920x1080/5/left/full/05_left_full_5.png
# Match: predict label: 5 path:  ZENICA_IRIS/1920x1080/5/left/full/05_left_full_8.png
#
#
# Match: N query 6  closest to: 6 distance: 12.200306897915327
# Match: query   label: 5 path:  ZENICA_IRIS/1920x1080/5/left/full/05_left_full_3.png
# Match: predict label: 5 path:  ZENICA_IRIS/1920x1080/5/left/full/05_left_full_4.png
#
#
# Match: N query 7  closest to: 2 distance: 12.036388538421795
# Match: query   label: 5 path:  ZENICA_IRIS/1920x1080/5/left/full/05_left_full_1.png
# Match: predict label: 5 path:  ZENICA_IRIS/1920x1080/5/right/full/05_right_full_4.png
#
#
# Match: N query 8  closest to: 8 distance: 9.010651537235711
# Match: query   label: 2 path:  ZENICA_IRIS/1920x1080/2/right/full/02_right_full_7.png
# Match: predict label: 2 path:  ZENICA_IRIS/1920x1080/2/right/full/02_right_full_8.png
#
#
# Match: N query 9  closest to: 8 distance: 9.010651537235711
# Match: query   label: 2 path:  ZENICA_IRIS/1920x1080/2/right/full/02_right_full_5.png
# Match: predict label: 2 path:  ZENICA_IRIS/1920x1080/2/right/full/02_right_full_8.png
#
#
# Match: N query 10  closest to: 10 distance: 13.55402443443056
# Match: query   label: 2 path:  ZENICA_IRIS/1920x1080/2/right/full/02_right_full_3.png
# Match: predict label: 2 path:  ZENICA_IRIS/1920x1080/2/right/full/02_right_full_4.png
#
#
# Match: N query 11  closest to: 10 distance: 13.55402443443056
# Match: query   label: 2 path:  ZENICA_IRIS/1920x1080/2/right/full/02_right_full_1.png
# Match: predict label: 2 path:  ZENICA_IRIS/1920x1080/2/right/full/02_right_full_4.png
#
#
# Match: N query 12  closest to: 13 distance: 10.980665033486666
# Match: query   label: 2 path:  ZENICA_IRIS/1920x1080/2/left/full/02_left_full_2.png
# Match: predict label: 2 path:  ZENICA_IRIS/1920x1080/2/left/full/02_left_full_3.png
#
#
# Match: N query 13  closest to: 12 distance: 24.219464455187563
# Match: query   label: 2 path:  ZENICA_IRIS/1920x1080/2/left/full/02_left_full_4.png
# Match: predict label: 2 path:  ZENICA_IRIS/1920x1080/2/left/full/02_left_full_1.png
#
#
# Match: N query 14  closest to: 15 distance: 11.51665518098103
# Match: query   label: 2 path:  ZENICA_IRIS/1920x1080/2/left/full/02_left_full_6.png
# Match: predict label: 2 path:  ZENICA_IRIS/1920x1080/2/left/full/02_left_full_7.png
#
#
# Match: N query 15  closest to: 15 distance: 11.51665518098103
# Match: query   label: 2 path:  ZENICA_IRIS/1920x1080/2/left/full/02_left_full_8.png
# Match: predict label: 2 path:  ZENICA_IRIS/1920x1080/2/left/full/02_left_full_7.png
#
#
# Match: N query 16  closest to: 16 distance: 9.989358198687226
# Match: query   label: 6 path:  ZENICA_IRIS/1920x1080/6/right/full/06_right_full_1.png
# Match: predict label: 6 path:  ZENICA_IRIS/1920x1080/6/right/full/06_right_full_2.png
#
#
# Match: N query 17  closest to: 17 distance: 21.544532963950868
# Match: query   label: 6 path:  ZENICA_IRIS/1920x1080/6/right/full/06_right_full_7.png
# Match: predict label: 6 path:  ZENICA_IRIS/1920x1080/6/right/full/06_right_full_8.png
#
#
# Match: N query 18  closest to: 19 distance: 15.88593162160558
# Match: query   label: 6 path:  ZENICA_IRIS/1920x1080/6/right/full/06_right_full_5.png
# Match: predict label: 6 path:  ZENICA_IRIS/1920x1080/6/right/full/06_right_full_4.png
#
#
# Match: N query 19  closest to: 16 distance: 9.989358198687226
# Match: query   label: 6 path:  ZENICA_IRIS/1920x1080/6/right/full/06_right_full_3.png
# Match: predict label: 6 path:  ZENICA_IRIS/1920x1080/6/right/full/06_right_full_2.png
#
#
# Match: N query 20  closest to: 21 distance: 12.237891616244095
# Match: query   label: 6 path:  ZENICA_IRIS/1920x1080/6/left/full/06_left_full_5.png
# Match: predict label: 6 path:  ZENICA_IRIS/1920x1080/6/left/full/06_left_full_8.png
#
#
# Match: N query 21  closest to: 22 distance: 13.724246234033505
# Match: query   label: 6 path:  ZENICA_IRIS/1920x1080/6/left/full/06_left_full_2.png
# Match: predict label: 6 path:  ZENICA_IRIS/1920x1080/6/left/full/06_left_full_3.png
#
#
# Match: N query 22  closest to: 22 distance: 13.724246234033505
# Match: query   label: 6 path:  ZENICA_IRIS/1920x1080/6/left/full/06_left_full_4.png
# Match: predict label: 6 path:  ZENICA_IRIS/1920x1080/6/left/full/06_left_full_3.png
#
#
# Match: N query 23  closest to: 21 distance: 12.237891616244095
# Match: query   label: 6 path:  ZENICA_IRIS/1920x1080/6/left/full/06_left_full_1.png
# Match: predict label: 6 path:  ZENICA_IRIS/1920x1080/6/left/full/06_left_full_8.png
#
#
# Match: N query 24  closest to: 25 distance: 16.057250593761665
# Match: query   label: 3 path:  ZENICA_IRIS/1920x1080/3/left/full/03_left_full_2.png
# Match: predict label: 3 path:  ZENICA_IRIS/1920x1080/3/left/full/03_left_full_3.png
#
#
# Match: N query 25  closest to: 25 distance: 16.057250593761665
# Match: query   label: 3 path:  ZENICA_IRIS/1920x1080/3/left/full/03_left_full_4.png
# Match: predict label: 3 path:  ZENICA_IRIS/1920x1080/3/left/full/03_left_full_3.png
#
#
# Match: N query 26  closest to: 26 distance: 15.358520111477162
# Match: query   label: 3 path:  ZENICA_IRIS/1920x1080/3/left/full/03_left_full_6.png
# Match: predict label: 3 path:  ZENICA_IRIS/1920x1080/3/left/full/03_left_full_5.png
#
#
# Match: N query 27  closest to: 27 distance: 14.914980716724827
# Match: query   label: 3 path:  ZENICA_IRIS/1920x1080/3/left/full/03_left_full_8.png
# Match: predict label: 3 path:  ZENICA_IRIS/1920x1080/3/left/full/03_left_full_7.png
#
#
# Match: N query 28  closest to: 29 distance: 16.75649761741229
# Match: query   label: 3 path:  ZENICA_IRIS/1920x1080/3/right/full/03_right_full_2.png
# Match: predict label: 3 path:  ZENICA_IRIS/1920x1080/3/right/full/03_right_full_3.png
#
#
# Match: N query 29  closest to: 29 distance: 16.75649761741229
# Match: query   label: 3 path:  ZENICA_IRIS/1920x1080/3/right/full/03_right_full_4.png
# Match: predict label: 3 path:  ZENICA_IRIS/1920x1080/3/right/full/03_right_full_3.png
#
#
# Match: N query 30  closest to: 30 distance: 16.752476751063465
# Match: query   label: 3 path:  ZENICA_IRIS/1920x1080/3/right/full/03_right_full_6.png
# Match: predict label: 3 path:  ZENICA_IRIS/1920x1080/3/right/full/03_right_full_5.png
#
#
# Match: N query 31  closest to: 31 distance: 15.471702586742584
# Match: query   label: 3 path:  ZENICA_IRIS/1920x1080/3/right/full/03_right_full_8.png
# Match: predict label: 3 path:  ZENICA_IRIS/1920x1080/3/right/full/03_right_full_7.png
#
#
# Match: N query 32  closest to: 33 distance: 21.2738915267837
# Match: query   label: 4 path:  ZENICA_IRIS/1920x1080/4/right/full/04_right_full_7.png
# Match: predict label: 4 path:  ZENICA_IRIS/1920x1080/4/right/full/04_right_full_2.png
#
#
# Match: N query 33  closest to: 32 distance: 18.396485100760415
# Match: query   label: 4 path:  ZENICA_IRIS/1920x1080/4/right/full/04_right_full_6.png
# Match: predict label: 4 path:  ZENICA_IRIS/1920x1080/4/right/full/04_right_full_8.png
#
#
# Match: N query 34  closest to: 35 distance: 20.21876056558843
# Match: query   label: 4 path:  ZENICA_IRIS/1920x1080/4/right/full/04_right_full_5.png
# Match: predict label: 4 path:  ZENICA_IRIS/1920x1080/4/left/full/04_left_full_3.png
#
#
# Match: N query 35  closest to: 33 distance: 21.2738915267837
# Match: query   label: 4 path:  ZENICA_IRIS/1920x1080/4/right/full/04_right_full_4.png
# Match: predict label: 4 path:  ZENICA_IRIS/1920x1080/4/right/full/04_right_full_2.png
#
#
# Match: N query 36  closest to: 35 distance: 20.21876056558843
# Match: query   label: 4 path:  ZENICA_IRIS/1920x1080/4/right/full/04_right_full_3.png
# Match: predict label: 4 path:  ZENICA_IRIS/1920x1080/4/left/full/04_left_full_3.png
#
#
# Match: N query 37  closest to: 33 distance: 21.2738915267837
# Match: query   label: 4 path:  ZENICA_IRIS/1920x1080/4/right/full/04_right_full_1.png
# Match: predict label: 4 path:  ZENICA_IRIS/1920x1080/4/right/full/04_right_full_2.png
#
#
# Match: N query 38  closest to: 34 distance: 23.329106120527047
# Match: query   label: 4 path:  ZENICA_IRIS/1920x1080/4/left/full/04_left_full_2.png
# Match: predict label: 4 path:  ZENICA_IRIS/1920x1080/4/left/full/04_left_full_1.png
#
#
# Match: N query 39  closest to: 34 distance: 23.329106120527047
# Match: query   label: 4 path:  ZENICA_IRIS/1920x1080/4/left/full/04_left_full_4.png
# Match: predict label: 4 path:  ZENICA_IRIS/1920x1080/4/left/full/04_left_full_1.png
#
#
# Match: N query 40  closest to: 32 distance: 18.396485100760415
# Match: query   label: 4 path:  ZENICA_IRIS/1920x1080/4/left/full/04_left_full_6.png
# Match: predict label: 4 path:  ZENICA_IRIS/1920x1080/4/right/full/04_right_full_8.png
#
#
# Match: N query 41  closest to: 34 distance: 23.329106120527047
# Match: query   label: 4 path:  ZENICA_IRIS/1920x1080/4/left/full/04_left_full_8.png
# Match: predict label: 4 path:  ZENICA_IRIS/1920x1080/4/left/full/04_left_full_1.png
#
#
# Match: N query 42  closest to: 38 distance: 26.7466365803137
# Match: query   label: 10 path:  ZENICA_IRIS/1920x1080/10/right/full/10_right_full_8.png
# Match: predict label: 10 path:  ZENICA_IRIS/1920x1080/10/right/full/10_right_full_7.png
#
#
# Match: N query 43  closest to: 40 distance: 22.886253048790692
# Match: query   label: 10 path:  ZENICA_IRIS/1920x1080/10/right/full/10_right_full_2.png
# Match: predict label: 10 path:  ZENICA_IRIS/1920x1080/10/right/full/10_right_full_3.png
#
#
# Match: N query 44  closest to: 41 distance: 21.87687910455851
# Match: query   label: 10 path:  ZENICA_IRIS/1920x1080/10/right/full/10_right_full_4.png
# Match: predict label: 10 path:  ZENICA_IRIS/1920x1080/10/right/full/10_right_full_5.png
#
#
# Match: N query 45  closest to: 41 distance: 21.87687910455851
# Match: query   label: 10 path:  ZENICA_IRIS/1920x1080/10/right/full/10_right_full_6.png
# Match: predict label: 10 path:  ZENICA_IRIS/1920x1080/10/right/full/10_right_full_5.png
#
#
# Match: N query 46  closest to: 43 distance: 8.590691039385579
# Match: query   label: 10 path:  ZENICA_IRIS/1920x1080/10/left/full/10_left_full_1.png
# Match: predict label: 10 path:  ZENICA_IRIS/1920x1080/10/left/full/10_left_full_2.png
#
#
# Match: N query 47  closest to: 43 distance: 8.590691039385579
# Match: query   label: 10 path:  ZENICA_IRIS/1920x1080/10/left/full/10_left_full_3.png
# Match: predict label: 10 path:  ZENICA_IRIS/1920x1080/10/left/full/10_left_full_2.png
#
#
# Match: N query 48  closest to: 45 distance: 13.173199606254014
# Match: query   label: 10 path:  ZENICA_IRIS/1920x1080/10/left/full/10_left_full_5.png
# Match: predict label: 10 path:  ZENICA_IRIS/1920x1080/10/left/full/10_left_full_6.png
#
#
# Match: N query 49  closest to: 42 distance: 12.1478986516348
# Match: query   label: 10 path:  ZENICA_IRIS/1920x1080/10/left/full/10_left_full_7.png
# Match: predict label: 10 path:  ZENICA_IRIS/1920x1080/10/left/full/10_left_full_8.png
#
#
# Match: N query 50  closest to: 48 distance: 12.574092545576661
# Match: query   label: 7 path:  ZENICA_IRIS/1920x1080/7/left/full/07_left_full_6.png
# Match: predict label: 7 path:  ZENICA_IRIS/1920x1080/7/left/full/07_left_full_3.png
#
#
# Match: N query 51  closest to: 48 distance: 12.574092545576661
# Match: query   label: 7 path:  ZENICA_IRIS/1920x1080/7/left/full/07_left_full_4.png
# Match: predict label: 7 path:  ZENICA_IRIS/1920x1080/7/left/full/07_left_full_3.png
#
#
# Match: N query 52  closest to: 48 distance: 12.574092545576661
# Match: query   label: 7 path:  ZENICA_IRIS/1920x1080/7/left/full/07_left_full_2.png
# Match: predict label: 7 path:  ZENICA_IRIS/1920x1080/7/left/full/07_left_full_3.png
#
#
# Match: N query 53  closest to: 46 distance: 17.150388734376676
# Match: query   label: 7 path:  ZENICA_IRIS/1920x1080/7/left/full/07_left_full_8.png
# Match: predict label: 7 path:  ZENICA_IRIS/1920x1080/7/left/full/07_left_full_7.png
#
#
# Match: N query 54  closest to: 51 distance: 17.697293970186163
# Match: query   label: 7 path:  ZENICA_IRIS/1920x1080/7/right/full/07_right_full_6.png
# Match: predict label: 7 path:  ZENICA_IRIS/1920x1080/7/right/full/07_right_full_5.png
#
#
# Match: N query 55  closest to: 52 distance: 16.68045683969295
# Match: query   label: 7 path:  ZENICA_IRIS/1920x1080/7/right/full/07_right_full_4.png
# Match: predict label: 7 path:  ZENICA_IRIS/1920x1080/7/right/full/07_right_full_3.png
#
#
# Match: N query 56  closest to: 52 distance: 16.68045683969295
# Match: query   label: 7 path:  ZENICA_IRIS/1920x1080/7/right/full/07_right_full_2.png
# Match: predict label: 7 path:  ZENICA_IRIS/1920x1080/7/right/full/07_right_full_3.png
#
#
# Match: N query 57  closest to: 50 distance: 33.100283747721676
# Match: query   label: 7 path:  ZENICA_IRIS/1920x1080/7/right/full/07_right_full_8.png
# Match: predict label: 7 path:  ZENICA_IRIS/1920x1080/7/right/full/07_right_full_7.png
#
#
# Match: N query 58  closest to: 60 distance: 23.619083047069694
# Match: query   label: 9 path:  ZENICA_IRIS/1920x1080/9/right/full/09_right_full_7.png
# Match: predict label: 9 path:  ZENICA_IRIS/1920x1080/9/left/full/09_left_full_5.png
#
#
# Match: N query 59  closest to: 59 distance: 24.96747762519962
# Match: query   label: 9 path:  ZENICA_IRIS/1920x1080/9/right/full/09_right_full_1.png
# Match: predict label: 9 path:  ZENICA_IRIS/1920x1080/9/left/full/09_left_full_3.png
#
#
# Match: N query 60  closest to: 57 distance: 14.018681731889059
# Match: query   label: 9 path:  ZENICA_IRIS/1920x1080/9/right/full/09_right_full_3.png
# Match: predict label: 9 path:  ZENICA_IRIS/1920x1080/9/right/full/09_right_full_4.png
#
#
# Match: N query 61  closest to: 54 distance: 18.948624066245713
# Match: query   label: 9 path:  ZENICA_IRIS/1920x1080/9/right/full/09_right_full_5.png
# Match: predict label: 9 path:  ZENICA_IRIS/1920x1080/9/right/full/09_right_full_6.png
#
#
# Match: N query 62  closest to: 59 distance: 24.96747762519962
# Match: query   label: 9 path:  ZENICA_IRIS/1920x1080/9/left/full/09_left_full_2.png
# Match: predict label: 9 path:  ZENICA_IRIS/1920x1080/9/left/full/09_left_full_3.png
#
#
# Match: N query 63  closest to: 60 distance: 23.619083047069694
# Match: query   label: 9 path:  ZENICA_IRIS/1920x1080/9/left/full/09_left_full_4.png
# Match: predict label: 9 path:  ZENICA_IRIS/1920x1080/9/left/full/09_left_full_5.png
#
#
# Match: N query 64  closest to: 60 distance: 23.619083047069694
# Match: query   label: 9 path:  ZENICA_IRIS/1920x1080/9/left/full/09_left_full_6.png
# Match: predict label: 9 path:  ZENICA_IRIS/1920x1080/9/left/full/09_left_full_5.png
#
#
# Match: N query 65  closest to: 61 distance: 18.855066953068278
# Match: query   label: 9 path:  ZENICA_IRIS/1920x1080/9/left/full/09_left_full_8.png
# Match: predict label: 9 path:  ZENICA_IRIS/1920x1080/9/left/full/09_left_full_7.png
#
#
# Match: N query 66  closest to: 64 distance: 12.856600456301376
# Match: query   label: 8 path:  ZENICA_IRIS/1920x1080/8/left/full/08_left_full_1.png
# Match: predict label: 8 path:  ZENICA_IRIS/1920x1080/8/left/full/08_left_full_4.png
#
#
# Match: N query 67  closest to: 64 distance: 12.856600456301376
# Match: query   label: 8 path:  ZENICA_IRIS/1920x1080/8/left/full/08_left_full_3.png
# Match: predict label: 8 path:  ZENICA_IRIS/1920x1080/8/left/full/08_left_full_4.png
#
#
# Match: N query 68  closest to: 63 distance: 31.2608516314985
# Match: query   label: 8 path:  ZENICA_IRIS/1920x1080/8/left/full/08_left_full_5.png
# Match: predict label: 8 path:  ZENICA_IRIS/1920x1080/8/left/full/08_left_full_2.png
#
#
# Match: N query 69  closest to: 62 distance: 16.96769157466763
# Match: query   label: 8 path:  ZENICA_IRIS/1920x1080/8/left/full/08_left_full_7.png
# Match: predict label: 8 path:  ZENICA_IRIS/1920x1080/8/left/full/08_left_full_8.png
#
#
# Match: N query 70  closest to: 66 distance: 14.868986052042025
# Match: query   label: 8 path:  ZENICA_IRIS/1920x1080/8/right/full/08_right_full_4.png
# Match: predict label: 8 path:  ZENICA_IRIS/1920x1080/8/right/full/08_right_full_3.png
#
#
# Match: N query 71  closest to: 68 distance: 12.956571960129262
# Match: query   label: 8 path:  ZENICA_IRIS/1920x1080/8/right/full/08_right_full_6.png
# Match: predict label: 8 path:  ZENICA_IRIS/1920x1080/8/right/full/08_right_full_7.png
#
#
# Match: N query 72  closest to: 68 distance: 12.956571960129262
# Match: query   label: 8 path:  ZENICA_IRIS/1920x1080/8/right/full/08_right_full_8.png
# Match: predict label: 8 path:  ZENICA_IRIS/1920x1080/8/right/full/08_right_full_7.png
#
#
# Match: N query 73  closest to: 67 distance: 10.708442024441291
# Match: query   label: 8 path:  ZENICA_IRIS/1920x1080/8/right/full/08_right_full_2.png
# Match: predict label: 8 path:  ZENICA_IRIS/1920x1080/8/right/full/08_right_full_5.png
#
#
# Match: N query 74  closest to: 70 distance: 12.408558359319612
# Match: query   label: 1 path:  ZENICA_IRIS/1920x1080/1/left/full/01_left_full_2.png
# Match: predict label: 1 path:  ZENICA_IRIS/1920x1080/1/left/full/01_left_full_1.png
#
#
# Match: N query 75  closest to: 72 distance: 15.135775172202994
# Match: query   label: 1 path:  ZENICA_IRIS/1920x1080/1/left/full/01_left_full_4.png
# Match: predict label: 1 path:  ZENICA_IRIS/1920x1080/1/left/full/01_left_full_5.png
#
#
# Match: N query 76  closest to: 73 distance: 21.17027280030782
# Match: query   label: 1 path:  ZENICA_IRIS/1920x1080/1/left/full/01_left_full_6.png
# Match: predict label: 1 path:  ZENICA_IRIS/1920x1080/1/left/full/01_left_full_7.png
#
#
# Match: N query 77  closest to: 76 distance: 14.247278321672365
# Match: query   label: 1 path:  ZENICA_IRIS/1920x1080/1/left/full/01_left_full_8.png
# Match: predict label: 1 path:  ZENICA_IRIS/1920x1080/1/right/full/01_right_full_5.png
#
#
# Match: N query 78  closest to: 76 distance: 14.247278321672365
# Match: query   label: 1 path:  ZENICA_IRIS/1920x1080/1/right/full/01_right_full_2.png
# Match: predict label: 1 path:  ZENICA_IRIS/1920x1080/1/right/full/01_right_full_5.png
#
#
# Match: N query 79  closest to: 75 distance: 25.86167026256292
# Match: query   label: 1 path:  ZENICA_IRIS/1920x1080/1/right/full/01_right_full_4.png
# Match: predict label: 1 path:  ZENICA_IRIS/1920x1080/1/right/full/01_right_full_3.png
#
#
# Match: N query 80  closest to: 74 distance: 16.054327284584268
# Match: query   label: 1 path:  ZENICA_IRIS/1920x1080/1/right/full/01_right_full_6.png
# Match: predict label: 1 path:  ZENICA_IRIS/1920x1080/1/right/full/01_right_full_1.png
#
#
# Match: N query 81  closest to: 76 distance: 14.247278321672365
# Match: query   label: 1 path:  ZENICA_IRIS/1920x1080/1/right/full/01_right_full_8.png
# Match: predict label: 1 path:  ZENICA_IRIS/1920x1080/1/right/full/01_right_full_5.png

# %%
df_04_right_full_6 = df_zenica[df_zenica['src_file']=='04_right_full_6.png']

# %%
df_04_right_full_6
# Out:
#     label             src_file       split  is_query  is_gallery eye      ds  \
# 66      4  04_right_full_6.png  validation       1.0         0.0   R  zenica
#
#                                                  path
# 66  ZENICA_IRIS/1920x1080/4/right/full/04_right_fu...

# %%
df_zenica.at[66,'is_query']=1.0
df_zenica.at[66,'is_gallery']=0.0

# %%
df_zenica.iloc[66]['is_query']
# Out:
# 1.0

# %%
df04_right_full_4 = df_zenica[df_zenica['src_file']=='04_right_full_4.png']

# %%
df04_right_full_4
# Out:
#     label             src_file       split  is_query  is_gallery eye      ds  \
# 68      4  04_right_full_4.png  validation       1.0         0.0   R  zenica
#
#                                                  path
# 68  ZENICA_IRIS/1920x1080/4/right/full/04_right_fu...

# %%
df_zenica.at[68,'is_query']=1.0
df_zenica.at[68,'is_gallery']=0.0
