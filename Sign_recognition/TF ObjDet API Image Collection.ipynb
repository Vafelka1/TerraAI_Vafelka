# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.5.62-cp36-abi3-win_amd64.whl (35.4 MB)
# Requirement already satisfied: numpy>=1.19.3 in c:\d\anaconda\lib\site-packages (from opencv-python) (1.20.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.62

# %%
# Import opencv
import cv2

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# %% [markdown]
# # 2. Define Images to Collect

# %%
labels = ['thumbsup', 'thumbsdown', 'thankyou', 'livelong']
number_imgs = 10

# %% [markdown]
# # 3. Setup Folders

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
print(IMAGES_PATH)
# Out:
# Tensorflow\workspace\images\collectedimages

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# # 4. Capture Images

# %%
for label in labels:
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for thumbsup
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting images for thumbsdown
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting images for thankyou
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting images for livelong
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9

# %% [markdown]
# # 5. Image Labelling

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# Collecting pyqt5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# spyder 5.1.5 requires pyqt5<5.13, but you have pyqt5 5.15.6 which is incompatible.
#   Downloading PyQt5-5.15.6-cp36-abi3-win_amd64.whl (6.7 MB)
# Requirement already satisfied: lxml in c:\d\anaconda\lib\site-packages (4.6.3)
# Collecting lxml
#   Downloading lxml-4.7.1-cp39-cp39-win_amd64.whl (3.7 MB)
# Collecting PyQt5-sip<13,>=12.8
#   Downloading PyQt5_sip-12.9.0-cp39-cp39-win_amd64.whl (63 kB)
# Collecting PyQt5-Qt5>=5.15.2
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
# Installing collected packages: PyQt5-sip, PyQt5-Qt5, pyqt5, lxml
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.6.3
#     Uninstalling lxml-4.6.3:
#       Successfully uninstalled lxml-4.6.3
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.9.0 lxml-4.7.1 pyqt5-5.15.6

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}

# %%
if os.name == 'posix':
    # !make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.3ee4bdc8-753a-11ec-8562-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong/livelong.3ee4bdc8-753a-11ec-8562-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.43c82991-753a-11ec-b70a-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong/livelong.43c82991-753a-11ec-b70a-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.44ff45c9-753a-11ec-bd7f-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong/livelong.44ff45c9-753a-11ec-bd7f-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.48a77378-753a-11ec-bf40-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong/livelong.48a77378-753a-11ec-bf40-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.49de4a3d-753a-11ec-96b5-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong/livelong.49de4a3d-753a-11ec-96b5-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.476ecb8a-753a-11ec-a638-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong/livelong.476ecb8a-753a-11ec-a638-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.42900c14-753a-11ec-beef-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong/livelong.42900c14-753a-11ec-beef-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.46369f33-753a-11ec-b04e-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong/livelong.46369f33-753a-11ec-b04e-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.402228b5-753a-11ec-ae81-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong/livelong.402228b5-753a-11ec-ae81-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.4158166e-753a-11ec-9938-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong/livelong.4158166e-753a-11ec-9938-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.2eae527b-753a-11ec-b165-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.2eae527b-753a-11ec-b165-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.2feac233-753a-11ec-b3df-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.2feac233-753a-11ec-b3df-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.34cb7788-753a-11ec-9b54-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.34cb7788-753a-11ec-9b54-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.39ae6505-753a-11ec-ac08-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.39ae6505-753a-11ec-ac08-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.373c9807-753a-11ec-a7a3-e86a640bb8fe.jpg -> Annotation:C:/D/Tensorflow OD/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.373c9807-753a-11ec-a7a3-e86a640bb8fe.xml
# Image:C:\D\Tensorflow OD\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou